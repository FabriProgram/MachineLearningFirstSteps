# %%
# !pip install -q openpyxl # Instalación de Libreria para manejar archibos xls

# IMPORTACION DE LIBRERIAS Y UTILIDADES
import pandas as pd
import numpy as np
import matplotlib.pylot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from google.colab import files

# INVOCAR A LA FUNCIÓN PARA SUBIR ARCHIVOS EN UNA VARIABLE
print("Sube un archivo excel")
upload = files.upload()

# MIRAR DENTRO DE LA VARIABLE EL ARCHIVO CARGADO
# Y SUBIRLO (SIN MANEJO DE ERRORES)
for file_name in upload.keys():
    df = pd.read_excel(file_name)

print("Datos subidos correctamente")
display(df.head())

# TRANSFORAR LOS DATOS EN ARCHIVOS CON SKLEARN
# PARA USARLOS EN ALGORITMO
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# SINTETIZAR LA INFORMACIÓN PARA ENTRENAR
# AL ALGORITMO (METODO EL CODO)
inertia = []
k_range = range(1, 11)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# GRAFICAR CON MATPLOT.LIB
plt.figure(figsize=(8,4))
plt.plot(k_range, inertia, marker="o")
plt.title('Método del codo para la selección de K')
plt.xlabel('Número de Clusters')
plt.ylabel('Inercia')
plt.grid(True)
plt.show()

# ENTRENAMIENTO DE ALGORITMO CON SKLEARN(KMeans)
k_optimo = 4
modelo_kmenas = KMeans(n_cluster=k_optimo, random_state=42, n_init=10)
clusters = modelo_kmeans.fit_predict(X_scaled)
df['Cluster'] = clusters

# VISUALIZACION DE CLUSTERS
# (USANDO 2 VARIABLES PRINCIPALES SI HAY MUCHAS)
plt.figure(figsize=(10, 6))
sns.scatterplot(data_df, x=df.columns[2], y=df.columns[1], hue='Cluster', palette='Set2')
plt.title('Segentación de Clientes')
plt.xlabel(df.columns[2])
plt.ylabel(df.columns[1])
plt.grid(True)
plt.legend(title='Cluster')
plt.show()

# IMPRIMIR PROMEDIOS POR CLUSTER PARA REFERENCIA
print("Perfil promedio por cluster")
display(df.groupby('Cluster').mean().round(2))
